# %% [markdown]
# ### Data Mining and Machine Learning
# ### Recommendation Systems based on popularity
# ### Edgar Acuna
# ### The module Recommender is required
# ### Database: One Million of songs
# ### March 2022

# %%
import os
os.getcwd()
import pandas
import numpy as np
import Recommender
import warnings
warnings.filterwarnings('ignore')

# %%
#Reading a database of two millions user-songs. There are 76353 users and 10000 songs
url= 'https://academic.uprm.edu/eacuna/10000.txt'
song_df_1 = pandas.read_table(url,header=None)
song_df_1.columns = ['user_id', 'song_id', 'listen_count']
song_df_1.head()
# Out:
#                                     user_id             song_id  listen_count
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1

# %%
song_df_1['user_id'].unique().shape
# Out:
# (76353,)

# %%
### Reading a database of one million songs including Title and artist name
songs_metadata_file = 'https://academic.uprm.edu/eacuna/song_data.csv'
song_df_2 = pandas.read_csv(songs_metadata_file)
song_df_2.head()
# Out:
#               song_id              title  \
# 0  SOQMMHC12AB0180CB8       Silent Night
# 1  SOVFVAK12A8C1350D9        Tanssi vaan
# 2  SOGTUKN12AB017F4F1  No One Could Ever
# 3  SOBNYVR12A8C13558C      Si Vos Querés
# 4  SOHSBXH12A8C13B0DF   Tangle Of Aspens
#
#                                 release       artist_name  year
# 0                 Monster Ballads X-Mas  Faster Pussy cat  2003
# 1                           Karkuteillä  Karkkiautomaatti  1995
# 2                                Butter    Hudson Mohawke  2006
# 3                               De Culo       Yerba Brava  2003
# 4  Rene Ablaze Presents Winter Sessions        Der Mystic     0

# %%
song_df_2['song_id'].unique().shape
# Out:
# (999056,)

# %%
#Merging the two databases by song_id
song_df = pandas.merge(song_df_1, song_df_2.drop_duplicates(['song_id']), on="song_id", how="left")

# %%
song_df.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1
#
#              title                        release    artist_name  year
# 0         The Cove             Thicker Than Water   Jack Johnson     0
# 1  Entre Dos Aguas            Flamenco Para Niños  Paco De Lucia  1976
# 2         Stronger                     Graduation     Kanye West  2007
# 3   Constellations              In Between Dreams   Jack Johnson  2005
# 4     Learn To Fly  There Is Nothing Left To Lose   Foo Fighters  1999

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000000 entries, 0 to 1999999
# Data columns (total 7 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   user_id       object
#  1   song_id       object
#  2   listen_count  int64
#  3   title         object
#  4   release       object
#  5   artist_name   object
#  6   year          int64
# dtypes: int64(2), object(5)
# memory usage: 122.1+ MB

# %%
#Using only 100k songs
song_df = song_df.head(100000)

# %%
#Creating a column song in order to include the Title and the artist
song_df['song'] = song_df['title'].map(str) + " - " + song_df['artist_name']
song_df.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1
#
#              title                        release    artist_name  year  \
# 0         The Cove             Thicker Than Water   Jack Johnson     0
# 1  Entre Dos Aguas            Flamenco Para Niños  Paco De Lucia  1976
# 2         Stronger                     Graduation     Kanye West  2007
# 3   Constellations              In Between Dreams   Jack Johnson  2005
# 4     Learn To Fly  There Is Nothing Left To Lose   Foo Fighters  1999
#
#                               song
# 0          The Cove - Jack Johnson
# 1  Entre Dos Aguas - Paco De Lucia
# 2            Stronger - Kanye West
# 3    Constellations - Jack Johnson
# 4      Learn To Fly - Foo Fighters

# %%
#Sorting the songs according to its Popularity
song_df_grouped = song_df.groupby(['song']).agg({'listen_count': 'count'}).reset_index()
song_df_grouped.sort_values('listen_count',ascending = 0)
# Out:
#                                                    song  listen_count
# 7079                           Sehr kosmisch - Harmonia           427
# 9030                                       Undo - Björk           367
# 2052  Dog Days Are Over (Radio Edit) - Florence + Th...           363
# 9818                     You're The One - Dwight Yoakam           317
# 7067                              Secrets - OneRepublic           308
# ...                                                 ...           ...
# 8849                            Too Much - All Time Low             1
# 4578                 La Dosis Perfecta - Panteón Rococó             1
# 4586                           La Niña - Mala Rodriguez             1
# 1760                            Cult Logic - Miike Snow             1
# 1633       Congratulations - Blue October / Imogen Heap             1
#
# [9891 rows x 2 columns]

# %%
#Finding  the number of users in the samllest dataset
users = song_df['user_id'].unique()
len(users)
# Out:
# 3863

# %%
#Finsing the number of items in the samllest dataset
items = song_df['song'].unique()
len(items)
# Out:
# 9891

# %%
#Splitting the data in training and test sets
from sklearn.model_selection import train_test_split
train_data, test_data = train_test_split(song_df, test_size = 0.20, random_state=0)

# %%
#Creating the recomendation system using the training data
pr = Recommender.Popularity_Recommender()
pr.create(train_data, 'user_id', 'song')

# %%
pr.create
# Out:
# <bound method Popularity_Recommender.create of <Recommender.Popularity_Recommender object at 0x00000219D7B2E1C0>>

# %%
#List of recommending songs for the third  user
pr.recommend(users[2])
# Out:
#                                        user_id  \
# 7005  bd4c6e843f00bd476847fb75c47b4fb430a06856
# 2034  bd4c6e843f00bd476847fb75c47b4fb430a06856
# 8939  bd4c6e843f00bd476847fb75c47b4fb430a06856
# 9719  bd4c6e843f00bd476847fb75c47b4fb430a06856
# 6994  bd4c6e843f00bd476847fb75c47b4fb430a06856
# 6659  bd4c6e843f00bd476847fb75c47b4fb430a06856
# 3559  bd4c6e843f00bd476847fb75c47b4fb430a06856
# 2672  bd4c6e843f00bd476847fb75c47b4fb430a06856
# 8704  bd4c6e843f00bd476847fb75c47b4fb430a06856
# 3432  bd4c6e843f00bd476847fb75c47b4fb430a06856
# 2189  bd4c6e843f00bd476847fb75c47b4fb430a06856
# 8992  bd4c6e843f00bd476847fb75c47b4fb430a06856
# 5141  bd4c6e843f00bd476847fb75c47b4fb430a06856
# 5868  bd4c6e843f00bd476847fb75c47b4fb430a06856
# 1367  bd4c6e843f00bd476847fb75c47b4fb430a06856
#
#                                                    song  score  Rank
# 7005                           Sehr kosmisch - Harmonia    345   1.0
# 2034  Dog Days Are Over (Radio Edit) - Florence + Th...    290   2.0
# 8939                                       Undo - Björk    289   3.0
# 9719                     You're The One - Dwight Yoakam    255   4.0
# 6994                              Secrets - OneRepublic    249   5.0
# 6659                            Revelry - Kings Of Leon    245   6.0
# 3559  Horn Concerto No. 4 in E flat K495: II. Romanc...    213   7.0
# 2672                     Fireflies - Charttraxx Karaoke    204   8.0
# 8704                                 Tive Sim - Cartola    204   9.0
# 3432                           Hey_ Soul Sister - Train    183  10.0
# 2189                Drop The World - Lil Wayne / Eminem    177  11.0
# 8992                       Use Somebody - Kings Of Leon    168  12.0
# 5141                                   Marry Me - Train    163  13.0
# 5868                    OMG - Usher featuring will.i.am    163  14.0
# 1367  Catch You Baby (Steve Pitron & Max Sanna Radio...    158  15.0

# %%
#List of recommending songs for the 19th  user
pr.recommend(users[20])
# Out:
#                                        user_id  \
# 7005  0afaa5d9d04bf85af720fe8cc566a41ca3e41c97
# 2034  0afaa5d9d04bf85af720fe8cc566a41ca3e41c97
# 8939  0afaa5d9d04bf85af720fe8cc566a41ca3e41c97
# 9719  0afaa5d9d04bf85af720fe8cc566a41ca3e41c97
# 6994  0afaa5d9d04bf85af720fe8cc566a41ca3e41c97
# 6659  0afaa5d9d04bf85af720fe8cc566a41ca3e41c97
# 3559  0afaa5d9d04bf85af720fe8cc566a41ca3e41c97
# 2672  0afaa5d9d04bf85af720fe8cc566a41ca3e41c97
# 8704  0afaa5d9d04bf85af720fe8cc566a41ca3e41c97
# 3432  0afaa5d9d04bf85af720fe8cc566a41ca3e41c97
# 2189  0afaa5d9d04bf85af720fe8cc566a41ca3e41c97
# 8992  0afaa5d9d04bf85af720fe8cc566a41ca3e41c97
# 5141  0afaa5d9d04bf85af720fe8cc566a41ca3e41c97
# 5868  0afaa5d9d04bf85af720fe8cc566a41ca3e41c97
# 1367  0afaa5d9d04bf85af720fe8cc566a41ca3e41c97
#
#                                                    song  score  Rank
# 7005                           Sehr kosmisch - Harmonia    345   1.0
# 2034  Dog Days Are Over (Radio Edit) - Florence + Th...    290   2.0
# 8939                                       Undo - Björk    289   3.0
# 9719                     You're The One - Dwight Yoakam    255   4.0
# 6994                              Secrets - OneRepublic    249   5.0
# 6659                            Revelry - Kings Of Leon    245   6.0
# 3559  Horn Concerto No. 4 in E flat K495: II. Romanc...    213   7.0
# 2672                     Fireflies - Charttraxx Karaoke    204   8.0
# 8704                                 Tive Sim - Cartola    204   9.0
# 3432                           Hey_ Soul Sister - Train    183  10.0
# 2189                Drop The World - Lil Wayne / Eminem    177  11.0
# 8992                       Use Somebody - Kings Of Leon    168  12.0
# 5141                                   Marry Me - Train    163  13.0
# 5868                    OMG - Usher featuring will.i.am    163  14.0
# 1367  Catch You Baby (Steve Pitron & Max Sanna Radio...    158  15.0

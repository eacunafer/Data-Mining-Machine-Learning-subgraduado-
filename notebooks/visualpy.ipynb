# %% [markdown]
# ## ESMA 4016
# ## Edgar Acuna
# ### Graficas en Python usando cuatro librerias: ggplot, plotly, seaborn y bokeh (Python 2)

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import bokeh
import ggplot

# %%
# Otra forma de llamar a ggplot
from ggplot import *

# %%
#Funcion magica para que la grafica de matplotlib salga en la pantalla
# %matplotlib inline

# %%
#Leyendo los datos
datos1=pd.read_csv("http://academic.uprm.edu/eacuna/clase97.txt",sep=" ")

# %%
datos1.head()
# Out:
#    edad sexo escuela programa creditos   gpa  familia  hestud  htv
# 0    21    f    publ     biol      119  3.60        3      35   10
# 1    18    f    priv     mbio       15  3.60        3      30   10
# 2    19    f    priv     biot       73  3.61        5       5    7
# 3    20    f    priv     mbio        *  2.38        3      14    3
# 4    21    m    publ     pmed      114  3.15        2      25   25

# %%
# Histograma de gpa usando ggplot
p=ggplot(aes(x='gpa'),data=datos1)
p+geom_histogram(binwidth=.35)
# Out:
# <ggplot: (14569690)>

# %% [markdown]
# Notar que en lugar de 5 intervalos ggplot muestra 10 intervalos

# %%
# Histograma de gpa cpn 8 intervalos usando ggplot
p=ggplot(aes(x = 'mpg'),data=mtcars) 
p=p+geom_histogram(colour = "black" , fill = "red" , bins = 8)
p
# Out:
# <ggplot: (14883728)>

# %% [markdown]
# Nuevamente notar de que a pesar que se le pide 8 intervalos, ggplot muestra 8 intervalos. La funcion parece estar con errores aun

# %%
#Histogram de gpa usando seaborn
sns.distplot(datos1['gpa'],kde=False, color="blue")

# %%
#otra vez el histograma en seaborn usando 5 intervalos
sns.distplot(datos1['gpa'],bins=5, kde=False, color="cyan")

# %%
#Histograma usando plotly
import plotly 
import plotly.graph_objs as go
plotly.offline.init_notebook_mode(connected=True)

x = datos1['gpa']
data = [go.Histogram(x=x)]

plotly.offline.iplot(data, filename='histograma en plotly')
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="03ff0ffb-244b-4947-9334-8a8ba25d5912" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("03ff0ffb-244b-4947-9334-8a8ba25d5912", [{"x": [3.6, 3.6, 3.61, 2.38, 3.15, 3.17, 2.15, 3.86, 3.19, 3.66, 3.35, 3.17, 3.23, 3.36, 2.88, 2.8, 2.5, 3.46, 2.74, 3.07, 2.2, 2.39, 3.05, 3.55, 3.03, 3.61, 2.73, 3.54], "type": "histogram"}], {}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %% [markdown]
# Comentario: Me da la impresion de que la libreria mas estable es seaborn.
# Lo unico malo es que no hace pie charts

# %%
# haciendo un segundo ejemplo con el cojunto de dato mtcars que viene dentro de pandas
mtcars.head()
# Out:
#                 name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
#Haciendo el histograma cpn seaborn
sns.distplot(mtcars['mpg'],kde=False)

# %%
#Haciendo el histograma con ggplopt
p = ggplot(aes(x='mpg'), data=mtcars)
p+geom_histogram(fill="green")
# Out:
# <ggplot: (16227777)>

# %%
#haciendo el histograma con Bokeh
from bokeh.charts import Histogram
from bokeh.charts import defaults, show
from bokeh.io import output_notebook

# input options
output_notebook()
hist = Histogram(datos1['gpa'], title="Histograma de GPA")

show(hist)
# Out:
# C:\Users\edgar2017\Anaconda2\envs\ipykernel_py2\lib\site-packages\bokeh\util\deprecation.py:34: BokehDeprecationWarning:
"x_range":{"id":"e8b28d3e-8eb8-4b69-b6ce-34139cdb3049","type":"Range1d"},"x_scale":{"id":"90192046-e838-459e-a06f-ad14f8f02cfe","type":"LinearScale"},"y_range":{"id":"95798f9d-ff01-4b37-a21a-e5d13112444f","type":"Range1d"},"y_scale":{"id":"7755f233-2522-4936-b14c-4ff8db1a3cb3","type":"LinearScale"}},"id":"650832e4-1fd7-4b80-8f12-d4578f70f828","subtype":"Chart","type":"Plot"},{"attributes":{"data_source":{"id":"dc237c2a-4464-4e7b-9867-58f4e9c52dde","type":"ColumnDataSource"},"glyph":{"id":"a38994de-0ceb-446f-911c-5682c2868d84","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"37761f1d-19e1-4d2b-be4e-f73cf375d338","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"09dd8694-f9bd-4682-99c1-a18a1fd79e81","type":"PanTool"},{"id":"2acfbb19-388f-4a3f-b260-2a2cd075f613","type":"WheelZoomTool"},{"id":"6f0131e6-89b3-450b-abf2-8c54071cfc52","type":"BoxZoomTool"},{"id":"5700ccb8-1d76-4c59-8259-ea614897a2c3","type":"SaveTool"},{"id":"7be2d486-8c78-4070-9cfd-0845ada064aa","type":"ResetTool"},{"id":"15e96d88-f194-4e19-983e-8eb4efb69ce8","type":"HelpTool"}]},"id":"acb36e2d-640a-4583-adb3-8728c383e7ae","type":"Toolbar"},{"attribu ...

# %%
#Leyendo los datost")
df=pd.read_table("http://academic.uprm.edu/eacuna/eje1reg.txt",sep="\s+")
df.head()
# Out:
#    Est  CEEB   GPA
# 0    1   425  2.81
# 1    2   495  2.56
# 2    3   600  2.92
# 3    4   610  3.18
# 4    5   612  2.51

# %%
#scatterplot usando matplotlib
df.plot.scatter('CEEB','GPA')

# %%
#scatteplot usando seaborn
sns.set(style="ticks")
sns.lmplot("CEEB", "GPA", data=df, fit_reg=False)

# %%
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D
import random


fig = pyplot.figure()
ax = Axes3D(fig)

sequence_containing_x_vals = list(range(0, 100))
sequence_containing_y_vals = list(range(0, 100))
sequence_containing_z_vals = list(range(0, 100))

random.shuffle(sequence_containing_x_vals)
random.shuffle(sequence_containing_y_vals)
random.shuffle(sequence_containing_z_vals)

ax.scatter(sequence_containing_x_vals, sequence_containing_y_vals, sequence_containing_z_vals)
pyplot.show()

# %%
import plotly as py
import plotly.graph_objs as go

import numpy as np

x, y, z = np.random.multivariate_normal(np.array([0,0,0]), np.eye(3), 200).transpose()
trace1 = go.Scatter3d(
    x=x,
    y=y,
    z=z,
    mode='markers',
    marker=dict(
        size=12,
        line=dict(
            color='rgba(217, 217, 217, 0.14)',
            width=0.5
        ),
        opacity=0.8
    )
)

x2, y2, z2 = np.random.multivariate_normal(np.array([0,0,0]), np.eye(3), 200).transpose()
trace2 = go.Scatter3d(
    x=x2,
    y=y2,
    z=z2,
    mode='markers',
    marker=dict(
        color='rgb(127, 127, 127)',
        size=12,
        symbol='circle',
        line=dict(
            color='rgb(204, 204, 204)',
            width=1
        ),
        opacity=0.9
    )
)
data = [trace1, trace2]
layout = go.Layout(
    margin=dict(
        l=0,
        r=0,
        b=0,
        t=0
    )
)
fig = go.Figure(data=data, layout=layout)
py.offline.iplot(fig, filename='simple-3d-scatter')
# Out:
# <div id="79f6e076-4d3e-4df2-a35b-d52328cddf8c" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("79f6e076-4d3e-4df2-a35b-d52328cddf8c", [{"marker": {"opacity": 0.8, "line": {"color": "rgba(217, 217, 217, 0.14)", "width": 0.5}, "size": 12}, "mode": "markers", "y": [1.4912555264245972, 0.11694560423452988, -2.2531991709584913, -0.18655150133187282, -0.590021418836802, -0.628653046741391, 1.5172754544342204, -0.13964717713898908, 0.63360807208814, -0.41296359273098937, 1.7443940641138083, 0.6103223409048931, -0.8916792147458266, 0.5321380948632474, -1.2550773876148236, -0.2840528560530205, -0.010924533673960892, -0.32176819941134366, -0.7030882144171717, 0.6672532671269296, 2.265047203851697, -0.47615743364837365, -0.1104937784315605, -0.18032102579364845, 1.0462876467384379, 0.6734081770281555, 0.
# %% [markdown]
# ### Data Mining and Machine Learning
# #### Association Rules using the apyori module
#
# #### Edgar Acuna
# #### May 2021

# %%
import numpy as np  
import pandas as pd  
from apyori import apriori

# %% [markdown]
# ### Market basket of 7501 transactions and 20 items

# %%
#the data is available at https://stackabuse.com/association-rule-mining-via-apriori-algorithm-in-python/
store_data = pd.read_csv('https://academic.uprm.edu/eacuna/store_data.csv',header=None)  
store_data.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# ...

# %%
#converting the dataframe in a list
records = []  
for i in range(0, 7501):  
    records.append([str(store_data.values[i,j]) for j in range(0, 20)])

# %%
association_rules = apriori(records, min_support=0.007, min_confidence=0.2, min_lift=3, min_length=2)  
association_results = list(association_rules)

# %%
print(len(association_results))
# Out:
# 10

# %%
#printing the first two results
association_results[0:2]
# Out:
# [RelationRecord(items=frozenset({'ground beef', 'herb & pepper'}), support=0.015997866951073192, ordered_statistics=[OrderedStatistic(items_base=frozenset({'herb & pepper'}), items_add=frozenset({'ground beef'}), confidence=0.3234501347708895, lift=3.2919938411349285)]),
#  RelationRecord(items=frozenset({'olive oil', 'whole wheat pasta'}), support=0.007998933475536596, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole wheat pasta'}), items_add=frozenset({'olive oil'}), confidence=0.2714932126696833, lift=4.122410097642296)])]

# %%
#Printing the  association rules
for item in association_results:

    # first index of the inner list
    # Contains base item and add item
    pair = item[0] 
    print(pair)
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    #second index of the inner list
    print("Support: " + str(item[1]))

    #third index of the list located at 0th
    #of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# frozenset({'ground beef', 'herb & pepper'})
# Rule: ground beef -> herb & pepper
# Support: 0.015997866951073192
# Confidence: 0.3234501347708895
# Lift: 3.2919938411349285
# ...
# frozenset({'olive oil', 'whole wheat pasta'})
# Rule: olive oil -> whole wheat pasta
# Support: 0.007998933475536596
# Confidence: 0.2714932126696833
# Lift: 4.122410097642296
# ...
# frozenset({'ground beef', 'spaghetti', 'frozen vegetables'})
# Rule: ground beef -> spaghetti
# Support: 0.008665511265164644
# Confidence: 0.31100478468899523
# Lift: 3.165328208890303
# ...
# frozenset({'mineral water', 'shrimp', 'frozen vegetables'})
# Rule: mineral water -> shrimp
# Support: 0.007199040127982935
# Confidence: 0.30508474576271183
# Lift: 3.200616332819722
# ...
# frozenset({'ground beef', 'nan', 'herb & pepper'})
# Rule: ground beef -> nan
# Support: 0.015997866951073192
# Confidence: 0.3234501347708895
# Lift: 3.2919938411349285
# ...
# frozenset({'spaghetti', 'olive oil', 'milk'})
# Rule: spaghetti -> olive oil
# ...

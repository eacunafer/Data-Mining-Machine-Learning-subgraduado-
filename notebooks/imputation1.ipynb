# %% [markdown]
# ## Lab 1 ESMA 4016
# ###  Edgar Acuna
# ### Imputacion I: Leyendo datos y contando los missing values
# #### Dataset: Adult tambien conocido como census disponible en la UCI

# %%
import pandas as pd

# %%
#leyendo los datos adult de la UCI

df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data', 
    header=None, 
    sep=',',na_values=[' ?'])

df.columns=['v1', 'v2', 'v3', 'v4', 'v5','v6','v7','v8','v9','v10','v11','v12','v13','v14','class']

# %%
#otra forma de leer los datos
# Load CSV using Pandas from URL
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data"
names = ['v1', 'v2', 'v3', 'v4', 'v5', 'v6', 'v7', 'v8','v9','v10','v11','v12','v13','v14','class']
data = pd.read_csv(url, names=names,na_values=[' ?'])
print(data.shape) #imprimiendo la dimension de los datos
# Out:
# (32561, 15)

# %%
#informacion acerca del dataset que permite ver que hay missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# v1       32561 non-null int64
# v2       30725 non-null object
# v3       32561 non-null int64
# v4       32561 non-null object
# v5       32561 non-null int64
# v6       32561 non-null object
# v7       30718 non-null object
# v8       32561 non-null object
# v9       32561 non-null object
# v10      32561 non-null object
# v11      32561 non-null int64
# v12      32561 non-null int64
# v13      32561 non-null int64
# v14      31978 non-null object
# class    32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# Notar que las colunas v2, v7 y v14 tienen distintos numeros de  entradas que las otras columnas

# %%
#imprimiendo los primeros 20 elementos de la tabla
df.head(20)
# Out:
#     v1                 v2      v3             v4  v5                      v6  \
# 0   39          State-gov   77516      Bachelors  13           Never-married
# 1   50   Self-emp-not-inc   83311      Bachelors  13      Married-civ-spouse
# 2   38            Private  215646        HS-grad   9                Divorced
# 3   53            Private  234721           11th   7      Married-civ-spouse
# 4   28            Private  338409      Bachelors  13      Married-civ-spouse
# 5   37            Private  284582        Masters  14      Married-civ-spouse
# 6   49            Private  160187            9th   5   Married-spouse-absent
# 7   52   Self-emp-not-inc  209642        HS-grad   9      Married-civ-spouse
# 8   31            Private   45781        Masters  14           Never-married
# 9   42            Private  159449      Bachelors  13      Married-civ-spouse
# 10  37            Private  280464   Some-college  10      Married-civ-spouse
# ...

# %%
#imprimiendo las ultimas 5 filas de la tabla
df.tail()
# Out:
#        v1             v2      v3           v4  v5                   v6  \
# 32556  27        Private  257302   Assoc-acdm  12   Married-civ-spouse
# 32557  40        Private  154374      HS-grad   9   Married-civ-spouse
# 32558  58        Private  151910      HS-grad   9              Widowed
# 32559  22        Private  201490      HS-grad   9        Never-married
# 32560  52   Self-emp-inc  287927      HS-grad   9   Married-civ-spouse
#
#                        v7          v8      v9      v10    v11  v12  v13  \
# 32556        Tech-support        Wife   White   Female      0    0   38
# 32557   Machine-op-inspct     Husband   White     Male      0    0   40
# 32558        Adm-clerical   Unmarried   White   Female      0    0   40
# 32559        Adm-clerical   Own-child   White     Male      0    0   20
# 32560     Exec-managerial        Wife   White   Female  15024    0   40
#
#                   v14   class
# 32556   United-States   <=50K
# 32557   United-States    >50K
# ...

# %%
#Imprimiendo la dimension de los datos
print(df.shape)
# Out:
# (32561, 15)

# %%
#cotejando si la tabla tiene missing values
df.isnull()
# Out:
#           v1     v2     v3     v4     v5     v6     v7     v8     v9    v10  \
# 0      False  False  False  False  False  False  False  False  False  False
# 1      False  False  False  False  False  False  False  False  False  False
# 2      False  False  False  False  False  False  False  False  False  False
# 3      False  False  False  False  False  False  False  False  False  False
# 4      False  False  False  False  False  False  False  False  False  False
# 5      False  False  False  False  False  False  False  False  False  False
# 6      False  False  False  False  False  False  False  False  False  False
# 7      False  False  False  False  False  False  False  False  False  False
# 8      False  False  False  False  False  False  False  False  False  False
# 9      False  False  False  False  False  False  False  False  False  False
# 10     False  False  False  False  False  False  False  False  False  False
# ...

# %%
#Hallando el numero de entradas de la tabla que son missing
df.isnull().sum().sum()
# Out:
# 4262

# %%
colmiss=df.columns[df.isnull().any()].tolist()

# %%
#Hallando el numero de entradas missing de cada columna
df[colmiss].isnull().sum()
# Out:
# v2     1836
# v7     1843
# v14     583
# dtype: int64

# %%
#Otra manera de hallar el numero de entradas missings en cada columna
df.apply(lambda x: sum(x.isnull().values), axis = 0)
# Out:
# v1          0
# v2       1836
# v3          0
# v4          0
# v5          0
# v6          0
# v7       1843
# v8          0
# v9          0
# v10         0
# v11         0
# v12         0
# v13         0
# v14       583
# class       0
# dtype: int64

# %%
#Hallando el numero de filas con missing
df.isnull().T.any().T.sum()
# Out:
# 2399

# %%
#Otra manera: Hallando el numero de filas que tienen missings
sum(df.apply(lambda x: sum(x.isnull().values), axis = 1)>0)
# Out:
# 2399

# %%
#Una tercera manera de hallar el numero de filas con missings
sum([True for idx,row in df.iterrows() if any(row.isnull())])
# Out:
# 2399

# %%
#Eliminando las filas que tienen missing
dfclean=df.dropna()

# %%
# tamano de la tabla despues de eliminar los missings
print dfclean.shape
# Out:
# (30162, 15)

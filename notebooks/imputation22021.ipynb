# %% [markdown]
# ## Data Mining and Machine Learning
# ### Edgar Acuna
# #### September 2021
# ###  mean/median/mode Imputation in datasets with mixed attributes: Census Dataset

# %%
import pandas as pd
datos=pd.read_csv('http://academic.uprm.edu/eacuna/census.csv',sep=",",na_values=[' ?'])
#datos = pd.read_csv('c://PW-PR/census.csv', sep=',',na_values=[' ?'])
print(datos.shape)
# Out:
# (32561, 15)

# %%
datos.head()
# Out:
#    age         employment  final-weight   education  education.num  \
# 0   39          State-gov         77516   Bachelors             13
# 1   50   Self-emp-not-inc         83311   Bachelors             13
# 2   38            Private        215646     HS-grad              9
# 3   53            Private        234721        11th              7
# 4   28            Private        338409   Bachelors             13
#
#         marital.status                 job    relationship    race   gender  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours.per.week  native.country  salary
# ...

# %%
#Excluyendo la columna de clase: class
x=datos.iloc[:,:-1]

# %%
x.head(20)
# Out:
#     age         employment  final-weight      education  education.num  \
# 0    39          State-gov         77516      Bachelors             13
# 1    50   Self-emp-not-inc         83311      Bachelors             13
# 2    38            Private        215646        HS-grad              9
# 3    53            Private        234721           11th              7
# 4    28            Private        338409      Bachelors             13
# 5    37            Private        284582        Masters             14
# 6    49            Private        160187            9th              5
# 7    52   Self-emp-not-inc        209642        HS-grad              9
# 8    31            Private         45781        Masters             14
# 9    42            Private        159449      Bachelors             13
# 10   37            Private        280464   Some-college             10
# 11   30          State-gov        141297      Bachelors             13
# ...

# %% [markdown]
# ### Since the missing values are in categorial features we use mode imputation

# %%
#computing the mode of one column
y=datos['education.num']
y.value_counts().index[0]
# Out:
# 9

# %%
y.mode()[0]
# Out:
# 9

# %%
#computing the mode of all the columns using pandas
datos.mode().iloc[0]
# Out:
# age                              36.0
# employment                    Private
# final-weight                   123011
# education                     HS-grad
# education.num                     9.0
# marital.status     Married-civ-spouse
# job                    Prof-specialty
# relationship                  Husband
# race                            White
# gender                           Male
# capital-gain                      0.0
# capital-loss                      0.0
# hours.per.week                   40.0
# native.country          United-States
# salary                          <=50K
# Name: 0, dtype: object

# %%
#imputando los valores missing usando la moda
datos.fillna(datos.mode().iloc[0])
# Out:
#        age         employment  final-weight    education  education.num  \
# 0       39          State-gov         77516    Bachelors             13
# 1       50   Self-emp-not-inc         83311    Bachelors             13
# 2       38            Private        215646      HS-grad              9
# 3       53            Private        234721         11th              7
# 4       28            Private        338409    Bachelors             13
# ...    ...                ...           ...          ...            ...
# 32556   27            Private        257302   Assoc-acdm             12
# 32557   40            Private        154374      HS-grad              9
# 32558   58            Private        151910      HS-grad              9
# 32559   22            Private        201490      HS-grad              9
# 32560   52       Self-emp-inc        287927      HS-grad              9
#
#             marital.status                 job    relationship    race  \
# ...

# %% [markdown]
# Another way to carry out mode imputation

# %%
dfclean = x.apply(lambda x:x.fillna(x.value_counts().index[0]))

# %% [markdown]
# Checking that the dataset is complete

# %%
dfclean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   employment      32561 non-null  object
#  2   final-weight    32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   job             32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   gender          32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  object
# dtypes: int64(6), object(8)
# memory usage: 3.5+ MB

# %%
dfclean.head(20)
# Out:
#     age         employment  final-weight      education  education.num  \
# 0    39          State-gov         77516      Bachelors             13
# 1    50   Self-emp-not-inc         83311      Bachelors             13
# 2    38            Private        215646        HS-grad              9
# 3    53            Private        234721           11th              7
# 4    28            Private        338409      Bachelors             13
# 5    37            Private        284582        Masters             14
# 6    49            Private        160187            9th              5
# 7    52   Self-emp-not-inc        209642        HS-grad              9
# 8    31            Private         45781        Masters             14
# 9    42            Private        159449      Bachelors             13
# 10   37            Private        280464   Some-college             10
# 11   30          State-gov        141297      Bachelors             13
# ...

# %% [markdown]
# ### Imputacion por la media si la variable es cuantitativa y por la moda si la variable es  cualitativa . Uso de scikit-learn

# %%
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.base import TransformerMixin

class DataFrameImputer(TransformerMixin):

    def fit(self, X, y=None):

        self.fill = pd.Series([X[c].value_counts().index[0]
            if X[c].dtype == np.dtype('O') else X[c].mean() for c in X],
            index=X.columns)

        return self

    def transform(self, X, y=None):
        return X.fillna(self.fill)

# %% [markdown]
# Applying to a small dataset

# %%
X1 = pd.DataFrame({'ciudad':['tokyo', np.NaN, 'london', 'seattle', 'san francisco', 'san juan'], 
          'var_binaria':['yes', 'no', np.NaN, 'no', 'no', 'yes'], 
          'var_ordinal':['somewhat like', 'like', 'somewhat like', 'like', 
                            'somewhat like', 'dislike'], 
          'var_cuantitativa':[1, 11, -.5, 10, np.NaN, 20]})
X1
# Out:
#           ciudad var_binaria    var_ordinal  var_cuantitativa
# 0          tokyo         yes  somewhat like               1.0
# 1            NaN          no           like              11.0
# 2         london         NaN  somewhat like              -0.5
# 3        seattle          no           like              10.0
# 4  san francisco          no  somewhat like               NaN
# 5       san juan         yes        dislike              20.0

# %%
X=X1
xt = DataFrameImputer().fit_transform(X)
xt
# Out:
#           ciudad var_binaria    var_ordinal  var_cuantitativa
# 0          tokyo         yes  somewhat like               1.0
# 1        seattle          no           like              11.0
# 2         london          no  somewhat like              -0.5
# 3        seattle          no           like              10.0
# 4  san francisco          no  somewhat like               8.3
# 5       san juan         yes        dislike              20.0

# %%
Applying the method to the Census dataset
# Out:
#   File "<ipython-input-15-ebf1d8d79d3c>", line 1
#     Applying the method to the Census dataset
#              ^
# SyntaxError: invalid syntax

# %%
X=x
xt = DataFrameImputer().fit_transform(X)
xt.head(20)

# %% [markdown]
# ### Imputacion por la mediana si la variable es cuantitativa y por la moda si la variable es  cualitativa. Uso de scikit-learn

# %%
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.base import TransformerMixin

class DataFrameImputer(TransformerMixin):
      
    def fit(self, X, y=None):
        """Impute missing values.

        Columns of dtype object are imputed with the most frequent value 
        in column.

        Columns of other types are imputed with mean of column.

        """

        self.fill = pd.Series([X[c].value_counts().index[0]
            if X[c].dtype == np.dtype('O') else X[c].median() for c in X],
            index=X.columns)

        return self

    def transform(self, X, y=None):
        return X.fillna(self.fill)

# %%
X=X1
xt = DataFrameImputer().fit_transform(X)
xt

# %% [markdown]
# Applying the method to the Census dataset

# %%
X=x
xt = DataFrameImputer().fit_transform(X)
xt.head(15)

# %% [markdown]
# #### Another way to carry out the above

# %%
from sklearn.impute import SimpleImputer
from sklearn.base import TransformerMixin

class MixImputer(TransformerMixin):
         def __init__(self, cols=None, strategy='mean'):
               self.cols = cols
               self.strategy = strategy

         def transform(self, df):
               X = df.copy()
               impute = SimpleImputer(strategy=self.strategy)
               if self.cols == None:
                      self.cols = list(X.columns)
               for col in self.cols:
                      if X[col].dtype == np.dtype('O') : 
                             X[col].fillna(X[col].value_counts().index[0], inplace=True)
                      else : X[col] = impute.fit_transform(X[[col]])

               return X

         def fit(self, *_):
               return self

# %%
imp = MixImputer(strategy='median')
clean=imp.fit_transform(X1)  
clean

# %% [markdown]
# Applying the method to the Census dataset

# %%
imp = MixImputer(strategy='mean')
clean=imp.fit_transform(x)  
clean.head(15)

# %% [markdown]
# ### Data Mining and Machine Learning
# ###  Edgar Acuna
# ###  Febrero 2021
# ### Visualization of Missing Values
#
# In this notebook will be using the library missingno created by Aleksey Bilogur https://github.com/ResidentMario
# The missigno module allow us   visualization of  missing values.
# Dataset: Census

# %%
import numpy as np
import missingno as msno
#from matplotlib import gridspec
#import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
#Leyendo la base de datos census de la internet
df = pd.read_csv('http://academic.uprm.edu/eacuna/census.csv',  sep=',',na_values=[' ?'])
df.columns
# Out:
# Index(['age', 'employment', 'final-weight', 'education', 'education.num',
#        'marital.status', 'job', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours.per.week', 'native.country',
#        'salary'],
#       dtype='object')

# %% [markdown]
# Displaying a bar chart that shows the amount of observations in each attribute

# %%
msno.bar(df,color="Green")

# %% [markdown]
# Displaying an image of the dataframe showing where the missing values are located

# %%
msno.matrix(df,color=(.2,.4,.6))
